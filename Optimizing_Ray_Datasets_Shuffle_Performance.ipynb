# %% [markdown]
# <a href="https://colab.research.google.com/github/daisysong76/ray_llm-vlm/blob/main/Optimizing_Ray_Datasets_Shuffle_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project Title:  "Optimizing Ray Datasets Shuffle Performance for Large-Scale Training with Apache Arrow"
#
# Description: Benchmark and optimize different shuffling techniques within Ray Datasets using Apache Arrow features (e.g., different partitioning strategies, in-memory vs. disk-based shuffle) to improve data distribution uniformity and shuffle speed for large-scale ML training workloads.
# Why Relevant: Directly addresses performance optimization, large-scale dataset processing, and relevance to ML training pipelines.
# Technologies: Ray Datasets, Apache Arrow, Python, Benchmarking tools.

# %% [markdown]
# Project Title:  "Optimizing Ray Datasets Shuffle Performance for Large-Scale Training with Apache Arrow"
#
# Description: Benchmark and optimize different shuffling techniques within Ray Datasets using Apache Arrow features (e.g., different partitioning strategies, in-memory vs. disk-based shuffle) to improve data distribution uniformity and shuffle speed for large-scale ML training workloads.
# Why Relevant: Directly addresses performance optimization, large-scale dataset processing, and relevance to ML training pipelines.
# Technologies: Ray Datasets, Apache Arrow, Python, Benchmarking tools.
